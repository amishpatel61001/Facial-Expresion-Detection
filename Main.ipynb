# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
import pandas as pd

# %%
def len_data(filename):
    anger_data = os.listdir(filename+'/Angry')
    happy_data = os.listdir(filename+'/Happy')
    sadness_data = os.listdir(filename+'/Sad')

    value = []
    for data in [anger_data,happy_data,sadness_data]:
        value.append(len(data))
        
    return sum(value)

# %%
filename = 'data'
print('Total Images in set : ' + str(len_data(filename)))
# Out:
# Total Images in set : 265

# %%
import cv2

def load_images_from_folder(folder):
    images = []
    
    folder1 = folder + '/Angry'
    for filename in os.listdir(folder1)[:20]:
        img = cv2.imread(os.path.join(os.getcwd(),folder1,filename))
        if img is not None:
            images.append(img)
            
    folder4 = folder + '/Happy'
    for filename in os.listdir(folder4)[:20]:
        img = cv2.imread(os.path.join(os.getcwd(),folder4,filename))
        if img is not None:
            images.append(img)
            
    folder5 = folder + '/Sad'
    for filename in os.listdir(folder5)[:20]:
        img = cv2.imread(os.path.join(os.getcwd(),folder5,filename))
        if img is not None:
            images.append(img)
    
    return images

# %%
images = load_images_from_folder('data')

# %%
fig, axis = plt.subplots(3,20,figsize=(20,7))
count = 0
for i in range(0,3):
    for j in range(0,20):
        img_rgb = cv2.cvtColor(images[count], cv2.COLOR_BGR2GRAY)
        axis[i,j].imshow(img_rgb)
        axis[i,j].axis('off')
        count = count + 1
        if i==0:
            axis[i,j].set_title('anger')
        elif i==1:
            axis[i,j].set_title('happy')
        elif i==2:
            axis[i,j].set_title('sad')

# %%
  def plot_data(filename):
    buildings_data = os.listdir(filename+'/Angry')
    mountain_data = os.listdir(filename+'/Happy')
    sea_data = os.listdir(filename+'/Sad')
    
    value = []
    for data in [buildings_data,mountain_data,sea_data]:
        value.append(len(data))
    
    sns.barplot(['angry','happy','sad'],value, palette = 'plasma')

# %%
filename = 'data'
plot_data(filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 filename = 'data'
# ----> 2 plot_data(filename)
#
# Cell In[14], line 10, in plot_data(filename)
#       7 for data in [buildings_data,mountain_data,sea_data]:
#       8     value.append(len(data))
# ---> 10 sns.barplot(['angry','happy','sad'],value, palette = 'plasma')
#      11 plt.show()
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given
